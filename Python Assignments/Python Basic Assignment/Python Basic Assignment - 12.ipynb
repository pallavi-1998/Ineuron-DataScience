# %% [markdown]
# # Python Basic Assignment - 12

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# - For PdfFileReader() file objects should be opened in rb -> read binary mode.
# - PdfFileWriter() file objects should be opened in wb -> write binary mode.

# %% [markdown]
# #### 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# - PdfFileReader.getPage(page_no)

# %%
from PyPDF2 import PdfFileReader
reads = PdfFileReader('verbal.pdf')
page = reads.getPage(9)
print(page.extract_text())
# Out:
#
# b) QRPS
# c) SPQR
# d) SRPQ
#
# Correct answer : d
#
# 33. AMEND (OPPOSITE)
# a) Worsen
# b) Enhance
# c) Repair
# d) Finish
#
# Correct answer : a
#
# 34. VETERAN (OPPOSITE)
# a) Old
# b) Inexperienced
# c) Expert
# d) Undisciplined
#
# Correct Answer : b
#
# 35.  The boss was unsure as to what triggered the argument between Shyam and Shankar.
# a) Spread
# b) Broke
# c) Halted
# d) Provoked
#
# Correct answer : d
#
# 36. (A) Those who do not understand (B) the meaning of loyalty does not achieve (C)
# love of their close ones.
# a) (A)
# b) (B)
# c) (C)
# d) No error
#
# Correct answer : b

# %% [markdown]
# #### 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# - getNumPages() - used to get total number of pages in pdf

# %%
from PyPDF2 import PdfFileReader
pdf_reader = PdfFileReader('verbal.pdf')
print(pdf_reader.getNumPages())
# Out:
# 53

# %% [markdown]
# #### 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %% [markdown]
# - by using object.decrypt('swordfish)

# %%
from PyPDF2 import PdfFileReader
pdf_reader = PdfFileReader('verbal.pdf')
if pdf_reader.isEncrypted: # to check whether the pdf is encrypted or not
    pdf_reader.decrypt("swordfish")
for page in pdf_reader.pages:
    print(page.extractText())
# Out:
#
# Verbal
#
# 1. “We need to call this _______ ” , Monika demanded.
# a) out
# b) at
# c) off
# d) away
#
#  Correct Answer: c
#
# 2. Heritage languages which form a part of India’s rich culture are becoming _______.
# a) extinctive
# b) extinguish
# c) extinction
# d) extinct
#
# Correct Answer: d
#
# 3. A) Jeet is very nice boy (B) add he always listen carefully (C) to what his parents
# have to say.
# a)   (A)
# a) (B)
# b) (C)
# c) (D)
#
# Correct Answer: b
#
# 4. Astronauts have completed a major mission in space. It was _____ a replacement of
# the fuel tank in one of the space stations.
# a) concerns
# b) concern
# c) concerning
# d) concerned
#
# Correct Answer: c
#
#
#
# 5. (A) Big brands like Sony, Samsung and (B) Nokia have been launched many phones
# having latest (C) features like Facebook application, Orkut tool and much more.
# a) (A)
# b) (B)
# c) (C)
# d) No error
#
# Correct Answer: b
#
# 6. VULNERABLE
# a) respectable
# b) weak
# c) decayed
# d) immature
#
#
# ...

# %% [markdown]
# #### 5. What methods do you use to rotate a page?

# %% [markdown]
# - rotateClockWise() -> For Clockwise rotation
# - rotateCounterClockWise() -> For Counter Clockwise rotation

# %% [markdown]
# #### 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# - Paragraph Object - A document contains multiple paragraphs. A paragraph begins on a new line and contains multiple runs. The Document object contains a list of Paragraph objects for the paragraphs in the document (A new paragraph begins whenever the user presses ENTER or RETURN while typing in a Word document).
# - Run Objects : Runs are contiguous groups of characters within a paragraph with the same style

# %% [markdown]
# #### 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %% [markdown]
# - by using doc.paragraphs

# %%
import docx
doc = docx.Document('test.docx')
print(doc.paragraphs)

# %% [markdown]
# #### 8. What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# - Run object has atribute such as font, size, color and other styling info associated with it.

# %% [markdown]
# #### 9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# - True -  the attribute (bold,italic etc) is always enabled.
# - False - the attribute (bold, italic etc) is always disabled.
# - None - defaults to whatever the runs's style is set to.

# %% [markdown]
# #### 10. How do you create a Document object for a new Word document?

# %% [markdown]
# - import docx
# doc = docx.Document(docx file_name)

# %% [markdown]
# #### 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %% [markdown]
# - from docx import Document
# doc = Document()
# doc.add_paragraph('Hello, there!')
# doc.save('hello.docx')

# %% [markdown]
# #### 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# - integer 0 to 4 as an argument to add_heading()
# - 0 makes heading Title style
# - 1 makes main heading
# - 2 to 4 for subheading on different levels
