# %% [markdown]
# # Assignment-21
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
# **Ans:** A probability distribution describes how a random variable is distributed.
#
# - It tells us which values a random variable is most likely to take on and which values are less likely. Based on the previous data and the occurences of the random event, we can predict the outcome in terms of probabilities.
# - describes all the possible values and likelihoods that a random variable can take within a given range.

# %% [markdown]
# #### Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there isone? Why are the latter considered “good enough”?

# %% [markdown]
# **Ans:** A **true random number** generator (TRNG), also known as a hardware random number generator (HRNG), does not use a computer algorithm. Instead, it uses an external unpredictable physical variable such as radioactive decay of isotopes or airwave static to generate random numbers.
#
# **Pseudorandom** is an approximated random number generated by software. Software running on regular hardware is highly deterministic, meaning that it runs the same every time. As such, it is difficult to generate a real random number in software as it runs too predictably to be considered random.

# %% [markdown]
# #### Q3. What are the two main factors that influence the behaviour of a "normal" probability distribution?

# %% [markdown]
# **Ans:** Normal Probabilty distribution are influenced by two factors **mean** and **variance**.

# %% [markdown]
# #### Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# **Ans:** Real Life Examples of Normal Distribution:
# 1. Heights of Person
# 2. Blood Presssure of Person
# 3. Rolling a Dice
# 4. Tossing a coin
# 5. IQ of People
# 6. Shoe size
# 7. Birth weight
# 8. Technical Stock Market

# %% [markdown]
# #### Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# **Ans:** for small values of σ2, the distribution is clustered close to the mean; as σ2 increases, the distribution deviates away from the mean. Despite the fact that the shapes are different, the total area under each curve which represents probability is equal to one.
# Variance will decrease with number of trials

# %% [markdown]
# #### Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# **Ans:** lists (list)

# %%
import random
x = [1,2,3, 5,1,8,9,10]
random.shuffle(x)
print(x)

x = "hellohow are you"
random.shuffle(x)
# Out:
# [1, 9, 2, 5, 1, 10, 3, 8]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 7
#       4 print(x)
#       6 x = "hellohow are you"
# ----> 7 random.shuffle(x)
#       9 x = (3, 4,5, 6, 7,)
#      10 random.shuffle(x)
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\random.py:307, in Random.shuffle(self, x, random)
#     304     for i in reversed(range(1, len(x))):
#     305         # pick an element in x[:i+1] with which to exchange x[i]
#     306         j = randbelow(i+1)
# --> 307         x[i], x[j] = x[j], x[i]
#     308 else:
#     309     _int = int
#
# TypeError: 'str' object does not support item assignment

# %%
x = (3, 4,5, 6, 7,)
random.shuffle(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 2
#       1 x = (3, 4,5, 6, 7,)
# ----> 2 random.shuffle(x)
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\random.py:307, in Random.shuffle(self, x, random)
#     304     for i in reversed(range(1, len(x))):
#     305         # pick an element in x[:i+1] with which to exchange x[i]
#     306         j = randbelow(i+1)
# --> 307         x[i], x[j] = x[j], x[i]
#     308 else:
#     309     _int = int
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Q7. Describe the math package's general categories of functions.

# %% [markdown]
# **Ans:** The Math package's general categories of functions are:
#
# 1. Trigonometric functions
# 2. Quadratic functions
# 3. Exponential functions
# 4. Hyperbolic functions
# 5. Periodic functions
# 6. Arithmetic functions
# 7. Logarithimic functions
# 8. Conversions to Integer

# %% [markdown]
# #### Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# **Ans:** Exponentiation and logarithms are inverse of each other.

# %% [markdown]
# #### Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# **Ans:** The Three Logarithmic Functions that Python supports are:
#
# 1. log2(x) - logarithmic value of x to base 2
# 2. log10(x) - logarithmic value of x to base 10
# 3. log1p(a) - This function is used to compute logarithm(1+a) .
