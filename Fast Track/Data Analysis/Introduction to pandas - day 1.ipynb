# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 9.7/9.7 MB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 498.1/498.1 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is 3C79-8284
#
#  Directory of d:\python_files\test
#
# 06-12-2022  18:06    <DIR>          .
# 06-12-2022  18:06    <DIR>          ..
# 01-11-2022  23:18            23,886 Assign_1.ipynb
# 04-12-2022  11:58             8,192 ineuron.db
# 05-12-2022  11:20            12,288 join_db.db
# 05-12-2022  18:59             7,205 map_reduce_filter.ipynb
# 04-12-2022  11:35             8,192 person.db
# 04-12-2022  06:29            26,716 practice_mongo.ipynb
# 07-12-2022  04:29             1,083 practice_pandas.ipynb
# 05-12-2022  16:45            26,388 sqlLite.ipynb
# 05-12-2022  18:45           236,180 vocab.enron.txt
# 05-12-2022  18:45            55,467 vocab.kos.txt
# 05-12-2022  18:45           100,807 vocab.nips.txt
# 05-12-2022  18:45         1,345,665 vocab.nytimes.txt
# 05-12-2022  18:45         1,460,248 vocab.pubmed.txt
#               13 File(s)      3,312,317 bytes
#                2 Dir(s)  773,670,465,536 bytes free

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\sample_text.csv')# putting r will converts a normal string to a raw string
# Out:
#       name           email_id    address  pincode       surname
# 0  pallavi   pallavi@gmail.com  varanasi   221001     prajapati
# 1    uttam     uttam@gmail.com   varansi   221901         kumar
# 2  ineuron  ineuron@ineuron.ai  banglore   560085  intelligence
# 3   pandas    pandas@gmail.com   chennai   225455     tutorial

# %%
import os 
l = os.listdir(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv')
print(l)
# Out:
# ['addresses.csv', 'contacts.csv', 'holiday_schedules.csv', 'locations.csv', 'mail_addresses.csv', 'organizations.csv', 'phones.csv', 'programs.csv', 'regular_schedules.csv', 'services.csv', 'taxonomy.csv']

# %%
df = pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\addresses.csv')

# %%
type(df)#tabular structure shown on console by pandas is called dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
import os 
l = os.listdir(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv')
path = r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv'
for file in l:
    x = f"{path}\{file}"
    print(pd.read_csv(x))
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\addresses.csv', header=None)
# Out:
#      0            1                           2          3  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\addresses.csv', names=['a','b','c','d','e','f','g','h'])
# Out:
#      a            b                           c          d  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
#if wev will provide extra names of col itwill create new col
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\addresses.csv', names=['a','b','c','d','e','f','g','h','i','j'])
# Out:
#      a            b                           c          d  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
# as lesser than required it will convert from left columns into row ids
df1 = pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\addresses.csv', names=['a','b','c','d','e'])

# %%
df1.dtypes
# Out:
# a    object
# b    object
# c    object
# d    object
# e    object
# dtype: object

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\sample_text.csv')# putting r will converts a normal string to a raw string
# Out:
#               name|email_id |address|pincode|surname
# 0  pallavi|pallavi@gmail.com|varanasi|221001|praj...
# 1         uttam|uttam@gmail.com|varansi|221901|kumar
# 2  ineuron|ineuron@ineuron.ai|banglore|560085|int...
# 3   pandas|pandas@gmail.com|chennai|225455|tutorial

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\sample_text.csv', sep='|')# putting r will converts a normal string to a raw string
# Out:
#       name           email_id    address  pincode       surname
# 0  pallavi   pallavi@gmail.com  varanasi   221001     prajapati
# 1    uttam     uttam@gmail.com   varansi   221901         kumar
# 2  ineuron  ineuron@ineuron.ai  banglore   560085  intelligence
# 3   pandas    pandas@gmail.com   chennai   225455     tutorial

# %%
pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\sample_text.csv', sep='| ',skiprows=[2,4])# putting r will converts a normal string to a raw string
# Out:
#       name           email_id    address  pincode       surname
# 0  pallavi   pallavi@gmail.com  varanasi   221001     prajapati
# 1  ineuron  ineuron@ineuron.ai  banglore   560085  intelligence

# %%
df = pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\sample_text.csv')# putting r will converts a normal string to a raw string

# %%
df.dtypes
# Out:
# name|email_id |address|pincode|surname    object
# dtype: object

# %%
df2 = pd.read_csv(r'C:\Users\Pallavi Prajapati\Downloads\Compressed\ohana-api-master\data\sample-csv\services.csv')

# %%
df2.dtypes #to know respective datatype of each column
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.head() # show only 5 records from start
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df2.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df2.tail()  # show only 5 records from buttom
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df2.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
df2.columns# show all col in a file
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df2['email'] #show single colom data
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
df2['application_process']
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
x = df2['name']

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
DATATYPE ====
dataframe => whole tabular structure (row * column)
series => single column or single row which is eqivalent to list but known as series instead

# %%
df2['name', 'location_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df2[['name', 'location_id','id']] #for multiple columns pas it whitin a square bracket as list of columns
# Out:
#                                     name  location_id  id
# 0        Fair Oaks Adult Activity Center            1   1
# 1       Second Career Employment Program            2   2
# 2                 Senior Peer Counseling            3   3
# 3               Family Visitation Center            4   4
# 4      Economic Self-Sufficiency Program            5   5
# 5   Little House Recreational Activities            6   6
# 6       Rosener House Adult Day Services            7   7
# 7         Meals on Wheels - South County            8   8
# 8                       Fair Oaks Branch            9   9
# 9                           Main Library           10  10
# 10                       Schaberg Branch           11  11
# 11                          Project Read           12  12
# 12                 Redwood Shores Branch           13  13
# 13                    Redwood City Corps           14  14
# 14           Adult Rehabilitation Center           15  15
# ...

# %%
a = df2[['name', 'location_id','id']]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df2[['name']]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:973, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pip install openpyxl
# Out:
# ...
#
# ...
#      ------------------------------------ 242.1/242.1 kB 345.1 kB/s eta 0:00:00
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx', sheet_name='Allocations')
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df1 = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df1.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
# type(df)
type(df1)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
for i in df1.sheet_names:
    pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = i)

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
pd.read_csv(r'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1349 try:
# -> 1350     h.request(req.get_method(), req.selector, req.data, headers,
#    1351               encode_chunked=req.has_header('Transfer-encoding'))
#    1352 except OSError as err: # timeout error
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1255, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1254 """Send a complete request to the server."""
# -> 1255 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
