# %% [markdown]
# https://gist.githubusercontent.com/DariaAlekseeva/299611a0daa6008685f7/raw/b431eb200bcafd2eba68a11ccbc80d051d3eeba9/titanic.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['data'])

# %%
#graph gives a pattern about dataset
df.plot()
# Out:
# <AxesSubplot: >

# %%
df1 = pd.DataFrame(np.random.randn(1000), columns=['data'],index= pd.date_range('2023/01/25', periods=1000))

# %%
df1
# Out:
#                 data
# 2023-01-25 -2.128433
# 2023-01-26 -1.133959
# 2023-01-27  1.690092
# 2023-01-28 -0.602249
# 2023-01-29  0.200468
# ...              ...
# 2025-10-16 -2.347612
# 2025-10-17  0.084791
# 2025-10-18 -0.908616
# 2025-10-19 -2.599468
# 2025-10-20 -1.137710
#
# [1000 rows x 1 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot: >

# %%
df1.plot(figsize= (20,10))
# Out:
# <AxesSubplot: >

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
df.plot(ax=axes[0,0])
# Out:
# <AxesSubplot: >

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.drop('id',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df.drop('id',axis=1)
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Pallavi Prajapati\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df.plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.head().plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.loc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
df.loc[5:11].plot(kind= 'bar')
# Out:
# <AxesSubplot: >

# %%
df.iloc[[3]].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.iloc[[3]].plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df.iloc[5:11].plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.head().plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',orientation= 'horizontal')
# Out:
# <AxesSubplot: xlabel='Frequency'>

# %%
df.hist(figsize=(20,10), color = 'g')
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize=(20,10), color = 'g', alpha=.5)
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.plot(kind='box', figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='box', figsize=(20,10),color={'boxes':'g', 'whiskers':'r'})
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='box', figsize=(20,10),color={'boxes':'g', 'whiskers':'r'},vert = False)
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='area',figsize=(20,10),alpha=.4)
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='area',figsize=(20,10),alpha=.4,stacked=False)
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot.scatter(x = 'sepal_length', y= 'petal_length')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=200)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=df['petal_width']*200)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length' , y = 'petal_length' , gridsize= 10 ,C ='sepal_width' )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
df.iloc[[0]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df1 = df.drop(columns='species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='0'>

# %%
pip install plotly
# Out:
# ...
#      ---------------------------------------- 15.2/15.2 MB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pip install cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iplot()
# Out:
# <div>                            <div id="217bd22a-2ed1-4a27-891c-525e44fabf3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
pip install --upgrade nbformat

# %%
df.iplot(x='sepal_length', y='petal_length')
# Out:
# <div>                            <div id="a1300508-3cab-45fa-bc80-d2c9163dbf2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length', y='petal_length',mode='markers')
# Out:
# <div>                            <div id="5266cfc9-b64f-4856-879f-3999a90c36ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length', y='petal_length',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="1d76d5e2-239b-4858-9dae-e38da4b68b94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(mode='markers',kind='scatter',size=10)
# Out:
# <div>                            <div id="ef89bd9f-d6d9-48d0-b087-65eac453ce8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble', x = 'sepal_length', y= 'petal_length',size='sepal_width')
# Out:
# <div>                            <div id="0319f02f-35f6-4672-ab81-03c7b98f5e37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="7c495011-9a37-4beb-96cd-b1f3560b1cbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d', x ='sepal_length' , y ='petal_length' , z= 'sepal_width' )
# Out:
# <div>                            <div id="1db499b7-bd3f-4f3e-b217-5c9eec5a6a8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d', x ='sepal_length' , y ='petal_length' , z= 'sepal_width' )
# Out:
# <div>                            <div id="e98f5078-3f37-48af-9675-dcdce0d1146a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iplot(kind='bubble3d', x ='sepal_length' , y ='petal_length' , z= 'sepal_width', size='petal_width')
# Out:
# <div>                            <div id="7259a510-2025-46c4-b4ec-6f6d7c714f36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#**********************************day2************************************************************

# %%
import seaborn as sns

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
sns.load_dataset('iris')

# %%
sns.scatterplot(x=df.sepal_length, y=df.petal_length)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.sepal_length,df.petal_length)

# %%
plt.plot(df.sepal_length,df.petal_length,'o')
plt.xlabel("sep_len")
plt.ylabel("pet_len")
# Out:
# Text(0, 0.5, 'pet_len')

# %%
plt.hist(df['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\Pallavi Prajapati\AppData\Local\Temp\ipykernel_13688\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <AxesSubplot: xlabel='sepal_length', ylabel='Density'>

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('tips.csv')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
df1.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 22.23       5.00   Male    No      Sun   Dinner  2       1
# 20.69       2.45   Female  No      Sat   Dinner  4       1
#             5.00   Male    No      Sun   Dinner  5       1
#                                                         ..
# 15.53       3.00   Male    Yes     Sat   Dinner  2       1
# 15.69       1.50   Male    Yes     Sun   Dinner  2       1
#             3.00   Male    Yes     Sat   Dinner  3       1
# 15.77       2.23   Female  No      Sat   Dinner  2       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Length: 243, dtype: int64

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='size')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=df1,style='time')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker',style='time')

# %%
sns.relplot(x='total_bill', y='tip',data=df1,size='size')

# %%
sns.relplot(x='total_bill', y='tip',kind='line',data=df1)

# %%
sns.relplot(x='total_bill', y='tip',data=df1,col='time')

# %%
sns.relplot(x='total_bill', y='tip',data=df1,col='size')

# %%
sns.relplot(x='total_bill', y='tip',data=df1,col='day')

# %%
sns.relplot(x='total_bill', y='tip',data=df1,col='sex')

# %%
# sns.relplot(x='total_bill', y='tip',data=df1,col='size')
sns.catplot(x='day',y='total_bill',data=df1)

# %%
sns.catplot(x='day',y='tip',data=df1)

# %%
sns.catplot(x='day',y='total_bill',data=df1,kind='swarm')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=df1)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=df1,hue='sex')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import seaborn as sns

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="9baaa3a8-83ca-4cc4-8812-93e1e97c681a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2 = pd.read_csv('https://gist.githubusercontent.com/DariaAlekseeva/299611a0daa6008685f7/raw/b431eb200bcafd2eba68a11ccbc80d051d3eeba9/titanic.csv')

# %%
df2.head()
# Out:
#    PassengerId Passengers  Class  \
# 0            1   Perished      3
# 1            2   Survived      1
# 2            3   Survived      3
# 3            4   Survived      1
# 4            5   Perished      3
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  19 - 40      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  19 - 40      1
# 2                             Heikkinen, Miss. Laina  female  19 - 40      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  19 - 40      1
# 4                           Allen, Mr. William Henry    male  19 - 40      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df2.iplot(x='Sex',y='Passengers', kind= 'bar')
# Out:
# <div>                            <div id="a8c2faad-8f6f-41a1-867e-d7efa1144338" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import pandas as pd

# %% [markdown]
# https://raw.githubusercontent.com/plotly/datasets/master/2015_Instant_Noodle_Consumption_Around_the_World.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/2015_Instant_Noodle_Consumption_Around_the_World.csv", index_col="Location")
